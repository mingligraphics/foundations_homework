# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/leiao/.pyenv/versions/3.7.1/lib/python3.7/site-packages (0.10.3)
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !touch .env

# %%
import os

API_KEY = os.getenv("DARKSKY_API_KEY")

API_KEY
# Out:
# 'ab9931a51f9f9e64b02fdaf244d7a5fc'

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
latitute = '33.3473'
longtitute = '120.1637'
url = 'https://api.darksky.net/forecast/' + API_KEY + "/" + latitute + "," + longtitute
response = requests.get(url)

# %%
place = response.json()

# %%
place
# Out:
# {'latitude': 33.3473,
#  'longitude': 120.1637,
#  'timezone': 'Asia/Shanghai',
#  'currently': {'time': 1560131666,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 79.04,
#   'apparentTemperature': 79.37,
#   'dewPoint': 63.01,
#   'humidity': 0.58,
#   'pressure': 1005.5,
#   'windSpeed': 12.58,
#   'windGust': 14.21,
#   'windBearing': 37,
#   'cloudCover': 0.48,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 333.92},
#  'hourly': {'summary': 'Partly cloudy later this morning.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560128400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.74,
#     'apparentTemperature': 77.16,
#     'dewPoint': 64.04,
#     'humidity': 0.65,
#     'pressure': 1005.4,
#     'windSpeed': 12.05,
#     'windGust': 15.24,
#     'windBearing': 36,
#     'cloudCover': 0.71,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 334.02},
#    {'time': 1560132000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.27,
#     'apparentTemperature': 79.6,
#     'dewPoint': 62.88,
#     'humidity': 0.57,
#     'pressure': 1005.51,
#     'windSpeed': 12.63,
#     'windGust': 14.1,
#     'windBearing': 38,
#     'cloudCover': 0.46,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 333.91},
#    {'time': 1560135600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.79,
#     'apparentTemperature': 81.82,
#     'dewPoint': 61.74,
#     'humidity': 0.52,
#     'pressure': 1005.6,
#     'windSpeed': 13.06,
#     'windGust': 13.44,
#     'windBearing': 39,
#     'cloudCover': 0.27,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 333.78},
#    {'time': 1560139200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.47,
#     'apparentTemperature': 81.33,
#     'dewPoint': 60.61,
#     'humidity': 0.51,
#     'pressure': 1005.69,
#     'windSpeed': 13.28,
#     'windGust': 13.64,
#     'windBearing': 39,
#     'cloudCover': 0.2,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 333.66},
#    {'time': 1560142800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.08,
#     'apparentTemperature': 80.83,
#     'dewPoint': 59.52,
#     'humidity': 0.5,
#     'pressure': 1005.75,
#     'windSpeed': 13.39,
#     'windGust': 14.17,
#     'windBearing': 40,
#     'cloudCover': 0.17,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 333.51},
#    {'time': 1560146400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.49,
#     'apparentTemperature': 79.49,
#     'dewPoint': 58.73,
#     'humidity': 0.49,
#     'pressure': 1005.8,
#     'windSpeed': 13.29,
#     'windGust': 14.7,
#     'windBearing': 40,
#     'cloudCover': 0.14,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 333.39},
#    {'time': 1560150000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.72,
#     'apparentTemperature': 78.72,
#     'dewPoint': 58.42,
#     'humidity': 0.5,
#     'pressure': 1005.8,
#     'windSpeed': 13.08,
#     'windGust': 15.17,
#     'windBearing': 40,
#     'cloudCover': 0.09,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 333.31},
#    {'time': 1560153600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.05,
#     'apparentTemperature': 78.05,
#     'dewPoint': 58.43,
#     'humidity': 0.51,
#     'pressure': 1005.77,
#     'windSpeed': 12.68,
#     'windGust': 15.58,
#     'windBearing': 41,
#     'cloudCover': 0.04,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 333.32},
#    {'time': 1560157200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.29,
#     'apparentTemperature': 77.29,
#     'dewPoint': 58.5,
#     'humidity': 0.52,
#     'pressure': 1005.83,
#     'windSpeed': 11.78,
#     'windGust': 15.32,
#     'windBearing': 46,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 333.51},
#    {'time': 1560160800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 74.81,
#     'apparentTemperature': 74.81,
#     'dewPoint': 58.57,
#     'humidity': 0.57,
#     'pressure': 1006,
#     'windSpeed': 9.95,
#     'windGust': 13.91,
#     'windBearing': 57,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.93},
#    {'time': 1560164400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 71.54,
#     'apparentTemperature': 71.54,
#     'dewPoint': 58.72,
#     'humidity': 0.64,
#     'pressure': 1006.26,
#     'windSpeed': 7.6,
#     'windGust': 11.82,
#     'windBearing': 72,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.53},
#    {'time': 1560168000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.9,
#     'apparentTemperature': 68.9,
#     'dewPoint': 58.91,
#     'humidity': 0.71,
#     'pressure': 1006.6,
#     'windSpeed': 5.67,
#     'windGust': 9.92,
#     'windBearing': 83,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.43},
#    {'time': 1560171600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.06,
#     'apparentTemperature': 67.06,
#     'dewPoint': 59.21,
#     'humidity': 0.76,
#     'pressure': 1007.12,
#     'windSpeed': 4.59,
#     'windGust': 8.52,
#     'windBearing': 90,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 336.93},
#    {'time': 1560175200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.62,
#     'apparentTemperature': 65.68,
#     'dewPoint': 59.56,
#     'humidity': 0.81,
#     'pressure': 1007.74,
#     'windSpeed': 3.92,
#     'windGust': 7.3,
#     'windBearing': 92,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 338.66},
#    {'time': 1560178800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.42,
#     'apparentTemperature': 64.53,
#     'dewPoint': 59.63,
#     'humidity': 0.84,
#     'pressure': 1008.16,
#     'windSpeed': 3.32,
#     'windGust': 6,
#     'windBearing': 93,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 340.01},
#    {'time': 1560182400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.22,
#     'apparentTemperature': 63.32,
#     'dewPoint': 59.22,
#     'humidity': 0.87,
#     'pressure': 1008.18,
#     'windSpeed': 2.31,
#     'windGust': 4.27,
#     'windBearing': 90,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 340.31},
#    {'time': 1560186000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.2,
#     'apparentTemperature': 62.25,
#     'dewPoint': 58.55,
#     'humidity': 0.88,
#     'pressure': 1008.02,
#     'windSpeed': 0.45,
#     'windGust': 2.73,
#     'windBearing': 346,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 340.16},
#    {'time': 1560189600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.95,
#     'apparentTemperature': 60.97,
#     'dewPoint': 57.94,
#     'humidity': 0.9,
#     'pressure': 1007.94,
#     'windSpeed': 1.49,
#     'windGust': 2.15,
#     'windBearing': 236,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 340.75},
#    {'time': 1560193200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.48,
#     'apparentTemperature': 59.49,
#     'dewPoint': 57.39,
#     'humidity': 0.93,
#     'pressure': 1008.01,
#     'windSpeed': 0.55,
#     'windGust': 2.25,
#     'windBearing': 308,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 342.85},
#    {'time': 1560196800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.32,
#     'apparentTemperature': 58.32,
#     'dewPoint': 56.91,
#     'humidity': 0.95,
#     'pressure': 1008.17,
#     'windSpeed': 2.27,
#     'windGust': 3.18,
#     'windBearing': 4,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 345.75},
#    {'time': 1560200400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.84,
#     'apparentTemperature': 58.84,
#     'dewPoint': 56.9,
#     'humidity': 0.93,
#     'pressure': 1008.42,
#     'windSpeed': 3.2,
#     'windGust': 4.69,
#     'windBearing': 343,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 348.06},
#    {'time': 1560204000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.93,
#     'apparentTemperature': 61.93,
#     'dewPoint': 57.74,
#     'humidity': 0.86,
#     'pressure': 1008.87,
#     'windSpeed': 4.05,
#     'windGust': 6.48,
#     'windBearing': 345,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 349.56},
#    {'time': 1560207600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.44,
#     'apparentTemperature': 67.44,
#     'dewPoint': 59.03,
#     'humidity': 0.74,
#     'pressure': 1009.44,
#     'windSpeed': 5.07,
#     'windGust': 8.55,
#     'windBearing': 2,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 350.46},
#    {'time': 1560211200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.44,
#     'apparentTemperature': 72.44,
#     'dewPoint': 60.03,
#     'humidity': 0.65,
#     'pressure': 1009.83,
#     'windSpeed': 6.09,
#     'windGust': 10.09,
#     'windBearing': 16,
#     'cloudCover': 0,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 350.71},
#    {'time': 1560214800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.82,
#     'apparentTemperature': 75.87,
#     'dewPoint': 60.45,
#     'humidity': 0.59,
#     'pressure': 1009.95,
#     'windSpeed': 7.13,
#     'windGust': 10.77,
#     'windBearing': 24,
#     'cloudCover': 0,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 349.97},
#    {'time': 1560218400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.23,
#     'apparentTemperature': 78.33,
#     'dewPoint': 60.58,
#     'humidity': 0.55,
#     'pressure': 1009.91,
#     'windSpeed': 8.2,
#     'windGust': 10.93,
#     'windBearing': 29,
#     'cloudCover': 0,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 348.54},
#    {'time': 1560222000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.01,
#     'apparentTemperature': 80.96,
#     'dewPoint': 60.51,
#     'humidity': 0.51,
#     'pressure': 1009.76,
#     'windSpeed': 9.14,
#     'windGust': 10.98,
#     'windBearing': 34,
#     'cloudCover': 0,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 346.97},
#    {'time': 1560225600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.72,
#     'apparentTemperature': 81.44,
#     'dewPoint': 60.23,
#     'humidity': 0.5,
#     'pressure': 1009.48,
#     'windSpeed': 10.01,
#     'windGust': 10.92,
#     'windBearing': 39,
#     'cloudCover': 0,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 345.43},
#    {'time': 1560229200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.47,
#     'apparentTemperature': 81.93,
#     'dewPoint': 59.8,
#     'humidity': 0.48,
#     'pressure': 1009.09,
#     'windSpeed': 10.77,
#     'windGust': 10.94,
#     'windBearing': 43,
#     'cloudCover': 0,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 343.75},
#    {'time': 1560232800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.57,
#     'apparentTemperature': 81.92,
#     'dewPoint': 59.4,
#     'humidity': 0.47,
#     'pressure': 1008.75,
#     'windSpeed': 11.24,
#     'windGust': 11.29,
#     'windBearing': 48,
#     'cloudCover': 0,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 342.26},
#    {'time': 1560236400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.65,
#     'apparentTemperature': 81.16,
#     'dewPoint': 59.02,
#     'humidity': 0.48,
#     'pressure': 1008.47,
#     'windSpeed': 11.31,
#     'windGust': 11.61,
#     'windBearing': 52,
#     'cloudCover': 0,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 341.17},
#    {'time': 1560240000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.15,
#     'apparentTemperature': 79.15,
#     'dewPoint': 58.64,
#     'humidity': 0.5,
#     'pressure': 1008.24,
#     'windSpeed': 11.06,
#     'windGust': 12.65,
#     'windBearing': 55,
#     'cloudCover': 0,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 340.26},
#    {'time': 1560243600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.08,
#     'apparentTemperature': 78.08,
#     'dewPoint': 58.46,
#     'humidity': 0.51,
#     'pressure': 1008.2,
#     'windSpeed': 10.57,
#     'windGust': 13.39,
#     'windBearing': 60,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 338.95},
#    {'time': 1560247200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.24,
#     'apparentTemperature': 75.24,
#     'dewPoint': 58.66,
#     'humidity': 0.56,
#     'pressure': 1008.47,
#     'windSpeed': 9.78,
#     'windGust': 13.65,
#     'windBearing': 69,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 336.83},
#    {'time': 1560250800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 71.63,
#     'apparentTemperature': 71.63,
#     'dewPoint': 59.08,
#     'humidity': 0.65,
#     'pressure': 1008.94,
#     'windSpeed': 8.77,
#     'windGust': 13.62,
#     'windBearing': 80,
#     'cloudCover': 0.06,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.27},
#    {'time': 1560254400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.81,
#     'apparentTemperature': 68.81,
#     'dewPoint': 59.5,
#     'humidity': 0.72,
#     'pressure': 1009.39,
#     'windSpeed': 7.92,
#     'windGust': 13.49,
#     'windBearing': 89,
#     'cloudCover': 0.17,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 332.34},
#    {'time': 1560258000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.25,
#     'apparentTemperature': 67.3,
#     'dewPoint': 59.89,
#     'humidity': 0.77,
#     'pressure': 1009.82,
#     'windSpeed': 7.43,
#     'windGust': 13.18,
#     'windBearing': 97,
#     'cloudCover': 0.43,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.79},
#    {'time': 1560261600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.2,
#     'apparentTemperature': 66.34,
#     'dewPoint': 60.3,
#     'humidity': 0.81,
#     'pressure': 1010.24,
#     'windSpeed': 7.13,
#     'windGust': 12.77,
#     'windBearing': 103,
#     'cloudCover': 0.76,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.88},
#    {'time': 1560265200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.25,
#     'apparentTemperature': 65.46,
#     'dewPoint': 60.56,
#     'humidity': 0.85,
#     'pressure': 1010.45,
#     'windSpeed': 6.88,
#     'windGust': 12.41,
#     'windBearing': 108,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.74},
#    {'time': 1560268800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.2,
#     'apparentTemperature': 64.45,
#     'dewPoint': 60.54,
#     'humidity': 0.88,
#     'pressure': 1010.33,
#     'windSpeed': 6.56,
#     'windGust': 12.25,
#     'windBearing': 114,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 330.87},
#    {'time': 1560272400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.35,
#     'apparentTemperature': 63.61,
#     'dewPoint': 60.34,
#     'humidity': 0.9,
#     'pressure': 1010.01,
#     'windSpeed': 6.21,
#     'windGust': 12.18,
#     'windBearing': 119,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.75},
#    {'time': 1560276000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.16,
#     'apparentTemperature': 62.44,
#     'dewPoint': 60.07,
#     'humidity': 0.93,
#     'pressure': 1009.75,
#     'windSpeed': 5.83,
#     'windGust': 12.09,
#     'windBearing': 123,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.13},
#    {'time': 1560279600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.65,
#     'apparentTemperature': 60.94,
#     'dewPoint': 59.59,
#     'humidity': 0.96,
#     'pressure': 1009.62,
#     'windSpeed': 5.21,
#     'windGust': 11.84,
#     'windBearing': 124,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.48},
#    {'time': 1560283200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.33,
#     'apparentTemperature': 59.61,
#     'dewPoint': 59.04,
#     'humidity': 0.99,
#     'pressure': 1009.53,
#     'windSpeed': 4.52,
#     'windGust': 11.58,
#     'windBearing': 124,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 330.25},
#    {'time': 1560286800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.34,
#     'apparentTemperature': 59.62,
#     'dewPoint': 58.98,
#     'humidity': 0.99,
#     'pressure': 1009.57,
#     'windSpeed': 4.33,
#     'windGust': 11.54,
#     'windBearing': 126,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 330.8},
#    {'time': 1560290400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.13,
#     'apparentTemperature': 62.39,
#     'dewPoint': 59.89,
#     'humidity': 0.92,
#     'pressure': 1009.81,
#     'windSpeed': 5.11,
#     'windGust': 12.02,
#     'windBearing': 136,
#     'cloudCover': 0.98,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 330.69},
#    {'time': 1560294000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.56,
#     'apparentTemperature': 66.8,
#     'dewPoint': 61.09,
#     'humidity': 0.83,
#     'pressure': 1010.16,
#     'windSpeed': 6.42,
#     'windGust': 12.72,
#     'windBearing': 148,
#     'cloudCover': 0.97,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 330.42},
#    {'time': 1560297600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70.76,
#     'apparentTemperature': 70.97,
#     'dewPoint': 61.67,
#     'humidity': 0.73,
#     'pressure': 1010.4,
#     'windSpeed': 7.47,
#     'windGust': 13.08,
#     'windBearing': 155,
#     'cloudCover': 0.96,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 330.44},
#    {'time': 1560301200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 74.44,
#     'apparentTemperature': 74.56,
#     'dewPoint': 61.17,
#     'humidity': 0.63,
#     'pressure': 1010.43,
#     'windSpeed': 7.86,
#     'windGust': 12.69,
#     'windBearing': 154,
#     'cloudCover': 0.97,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 331.2}]},
#  'daily': {'summary': 'No precipitation throughout the week, with high temperatures rising to 86°F on Friday.',
#   'icon': 'clear-day',
#   'data': [{'time': 1560096000,
#     'summary': 'Mostly cloudy in the morning.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560113448,
#     'sunsetTime': 1560164970,
#     'moonPhase': 0.25,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.0041,
#     'precipIntensityMaxTime': 1560096000,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperatureHigh': 80.79,
#     'temperatureHighTime': 1560135600,
#     'temperatureLow': 58.32,
#     'temperatureLowTime': 1560196800,
#     'apparentTemperatureHigh': 81.82,
#     'apparentTemperatureHighTime': 1560135600,
#     'apparentTemperatureLow': 58.32,
#     'apparentTemperatureLowTime': 1560196800,
#     'dewPoint': 62.21,
#     'humidity': 0.69,
#     'pressure': 1005.35,
#     'windSpeed': 9.15,
#     'windGust': 17.09,
#     'windGustTime': 1560117600,
#     'windBearing': 44,
#     'cloudCover': 0.45,
#     'uvIndex': 9,
#     'uvIndexTime': 1560139200,
#     'visibility': 10,
#     'ozone': 332.43,
#     'temperatureMin': 64.42,
#     'temperatureMinTime': 1560178800,
#     'temperatureMax': 80.79,
#     'temperatureMaxTime': 1560135600,
#     'apparentTemperatureMin': 64.53,
#     'apparentTemperatureMinTime': 1560178800,
#     'apparentTemperatureMax': 81.82,
#     'apparentTemperatureMaxTime': 1560135600},
#    {'time': 1560182400,
#     'summary': 'Mostly cloudy starting in the evening.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560199844,
#     'sunsetTime': 1560251396,
#     'moonPhase': 0.29,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0001,
#     'precipIntensityMaxTime': 1560222000,
#     'precipProbability': 0,
#     'temperatureHigh': 81.57,
#     'temperatureHighTime': 1560232800,
#     'temperatureLow': 59.33,
#     'temperatureLowTime': 1560283200,
#     'apparentTemperatureHigh': 81.93,
#     'apparentTemperatureHighTime': 1560229200,
#     'apparentTemperatureLow': 59.61,
#     'apparentTemperatureLowTime': 1560283200,
#     'dewPoint': 59.12,
#     'humidity': 0.69,
#     'pressure': 1009,
#     'windSpeed': 5.7,
#     'windGust': 13.65,
#     'windGustTime': 1560247200,
#     'windBearing': 52,
#     'cloudCover': 0.1,
#     'uvIndex': 9,
#     'uvIndexTime': 1560222000,
#     'visibility': 10,
#     'ozone': 341.86,
#     'temperatureMin': 58.32,
#     'temperatureMinTime': 1560196800,
#     'temperatureMax': 81.57,
#     'temperatureMaxTime': 1560232800,
#     'apparentTemperatureMin': 58.32,
#     'apparentTemperatureMinTime': 1560196800,
#     'apparentTemperatureMax': 81.93,
#     'apparentTemperatureMaxTime': 1560229200},
#    {'time': 1560268800,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560286242,
#     'sunsetTime': 1560337821,
#     'moonPhase': 0.32,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1560330000,
#     'precipProbability': 0,
#     'temperatureHigh': 84.15,
#     'temperatureHighTime': 1560319200,
#     'temperatureLow': 63.21,
#     'temperatureLowTime': 1560373200,
#     'apparentTemperatureHigh': 84.15,
#     'apparentTemperatureHighTime': 1560319200,
#     'apparentTemperatureLow': 63.78,
#     'apparentTemperatureLowTime': 1560373200,
#     'dewPoint': 60.29,
#     'humidity': 0.7,
#     'pressure': 1009.17,
#     'windSpeed': 8.47,
#     'windGust': 22.09,
#     'windGustTime': 1560348000,
#     'windBearing': 123,
#     'cloudCover': 0.98,
#     'uvIndex': 4,
#     'uvIndexTime': 1560304800,
#     'visibility': 10,
#     'ozone': 329.58,
#     'temperatureMin': 59.33,
#     'temperatureMinTime': 1560283200,
#     'temperatureMax': 84.15,
#     'temperatureMaxTime': 1560319200,
#     'apparentTemperatureMin': 59.61,
#     'apparentTemperatureMinTime': 1560283200,
#     'apparentTemperatureMax': 84.15,
#     'apparentTemperatureMaxTime': 1560319200},
#    {'time': 1560355200,
#     'summary': 'Mostly cloudy until afternoon.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560372642,
#     'sunsetTime': 1560424245,
#     'moonPhase': 0.36,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 81.85,
#     'temperatureHighTime': 1560405600,
#     'temperatureLow': 64.29,
#     'temperatureLowTime': 1560459600,
#     'apparentTemperatureHigh': 82.99,
#     'apparentTemperatureHighTime': 1560405600,
#     'apparentTemperatureLow': 64.6,
#     'apparentTemperatureLowTime': 1560459600,
#     'dewPoint': 63.05,
#     'humidity': 0.73,
#     'pressure': 1008,
#     'windSpeed': 10.29,
#     'windGust': 21.96,
#     'windGustTime': 1560355200,
#     'windBearing': 129,
#     'cloudCover': 0.46,
#     'uvIndex': 7,
#     'uvIndexTime': 1560402000,
#     'visibility': 10,
#     'ozone': 345.05,
#     'temperatureMin': 63.21,
#     'temperatureMinTime': 1560373200,
#     'temperatureMax': 81.85,
#     'temperatureMaxTime': 1560405600,
#     'apparentTemperatureMin': 63.78,
#     'apparentTemperatureMinTime': 1560373200,
#     'apparentTemperatureMax': 82.99,
#     'apparentTemperatureMaxTime': 1560405600},
#    {'time': 1560441600,
#     'summary': 'Partly cloudy overnight.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560459043,
#     'sunsetTime': 1560510668,
#     'moonPhase': 0.39,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0001,
#     'precipIntensityMaxTime': 1560481200,
#     'precipProbability': 0,
#     'temperatureHigh': 86.43,
#     'temperatureHighTime': 1560492000,
#     'temperatureLow': 64.32,
#     'temperatureLowTime': 1560542400,
#     'apparentTemperatureHigh': 86.43,
#     'apparentTemperatureHighTime': 1560492000,
#     'apparentTemperatureLow': 64.32,
#     'apparentTemperatureLowTime': 1560542400,
#     'dewPoint': 59.06,
#     'humidity': 0.6,
#     'pressure': 1007.34,
#     'windSpeed': 6.83,
#     'windGust': 22.45,
#     'windGustTime': 1560517200,
#     'windBearing': 120,
#     'cloudCover': 0.04,
#     'uvIndex': 8,
#     'uvIndexTime': 1560484800,
#     'visibility': 10,
#     'ozone': 365.62,
#     'temperatureMin': 64.29,
#     'temperatureMinTime': 1560459600,
#     'temperatureMax': 86.43,
#     'temperatureMaxTime': 1560492000,
#     'apparentTemperatureMin': 64.6,
#     'apparentTemperatureMinTime': 1560459600,
#     'apparentTemperatureMax': 86.43,
#     'apparentTemperatureMaxTime': 1560492000},
#    {'time': 1560528000,
#     'summary': 'Partly cloudy until afternoon.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560545445,
#     'sunsetTime': 1560597089,
#     'moonPhase': 0.43,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.0008,
#     'precipIntensityMaxTime': 1560535200,
#     'precipProbability': 0.11,
#     'precipType': 'rain',
#     'temperatureHigh': 85.46,
#     'temperatureHighTime': 1560567600,
#     'temperatureLow': 62.05,
#     'temperatureLowTime': 1560632400,
#     'apparentTemperatureHigh': 85.46,
#     'apparentTemperatureHighTime': 1560567600,
#     'apparentTemperatureLow': 62.43,
#     'apparentTemperatureLowTime': 1560632400,
#     'dewPoint': 57.81,
#     'humidity': 0.56,
#     'pressure': 1007.66,
#     'windSpeed': 6.02,
#     'windGust': 19.03,
#     'windGustTime': 1560528000,
#     'windBearing': 93,
#     'cloudCover': 0.36,
#     'uvIndex': 7,
#     'uvIndexTime': 1560567600,
#     'visibility': 10,
#     'ozone': 334.33,
#     'temperatureMin': 64.32,
#     'temperatureMinTime': 1560542400,
#     'temperatureMax': 85.46,
#     'temperatureMaxTime': 1560567600,
#     'apparentTemperatureMin': 64.32,
#     'apparentTemperatureMinTime': 1560542400,
#     'apparentTemperatureMax': 85.46,
#     'apparentTemperatureMaxTime': 1560567600},
#    {'time': 1560614400,
#     'summary': 'Partly cloudy in the morning.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560631849,
#     'sunsetTime': 1560683510,
#     'moonPhase': 0.46,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 81.41,
#     'temperatureHighTime': 1560661200,
#     'temperatureLow': 62.05,
#     'temperatureLowTime': 1560715200,
#     'apparentTemperatureHigh': 81.52,
#     'apparentTemperatureHighTime': 1560661200,
#     'apparentTemperatureLow': 62.46,
#     'apparentTemperatureLowTime': 1560715200,
#     'dewPoint': 60.25,
#     'humidity': 0.67,
#     'pressure': 1010.83,
#     'windSpeed': 9.03,
#     'windGust': 20.87,
#     'windGustTime': 1560697200,
#     'windBearing': 92,
#     'cloudCover': 0.17,
#     'uvIndex': 10,
#     'uvIndexTime': 1560654000,
#     'visibility': 10,
#     'ozone': 322.26,
#     'temperatureMin': 62.05,
#     'temperatureMinTime': 1560632400,
#     'temperatureMax': 81.41,
#     'temperatureMaxTime': 1560661200,
#     'apparentTemperatureMin': 62.43,
#     'apparentTemperatureMinTime': 1560632400,
#     'apparentTemperatureMax': 81.52,
#     'apparentTemperatureMaxTime': 1560661200},
#    {'time': 1560700800,
#     'summary': 'Mostly cloudy throughout the day and breezy starting in the afternoon, continuing until evening.',
#     'icon': 'wind',
#     'sunriseTime': 1560718255,
#     'sunsetTime': 1560769929,
#     'moonPhase': 0.49,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 81.69,
#     'temperatureHighTime': 1560747600,
#     'temperatureLow': 64.46,
#     'temperatureLowTime': 1560801600,
#     'apparentTemperatureHigh': 82.03,
#     'apparentTemperatureHighTime': 1560747600,
#     'apparentTemperatureLow': 65.04,
#     'apparentTemperatureLowTime': 1560801600,
#     'dewPoint': 60.61,
#     'humidity': 0.67,
#     'pressure': 1011.14,
#     'windSpeed': 11.75,
#     'windGust': 23,
#     'windGustTime': 1560772800,
#     'windBearing': 122,
#     'cloudCover': 0.76,
#     'uvIndex': 7,
#     'uvIndexTime': 1560744000,
#     'visibility': 10,
#     'ozone': 316.31,
#     'temperatureMin': 62.05,
#     'temperatureMinTime': 1560715200,
#     'temperatureMax': 81.69,
#     'temperatureMaxTime': 1560747600,
#     'apparentTemperatureMin': 62.46,
#     'apparentTemperatureMinTime': 1560715200,
#     'apparentTemperatureMax': 82.03,
#     'apparentTemperatureMaxTime': 1560747600}]},
#  'flags': {'sources': ['cmc', 'gfs', 'icon', 'isd', 'madis'],
#   'nearest-station': 28.91,
#   'units': 'us'},
#  'offset': 8}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
place.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'hourly', 'daily', 'flags', 'offset'])

# %%
print(place['currently'].keys())
print('---------------------------------------')
print("The current wind speed is", place['currently']['windSpeed'])
# Out:
# dict_keys(['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'ozone'])
# ---------------------------------------
# The current wind speed is 12.58

# %%
print("It feels",place['currently']['apparentTemperature'] - place['currently']['temperature'], "°F warmer.")
# Out:
# It feels 0.3299999999999983 °F warmer.

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
forecast = place['daily']['data'][0]
print("The visibility of the noon is", forecast['moonPhase'])
# Out:
# The visibility of the noon is 0.25

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
print("The difference between the high and low temperatures for today is", forecast['temperatureHigh'] - forecast['temperatureLow'],"°F.")
# Out:
# The difference between the high and low temperatures for today is 22.470000000000006 °F.

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
forecasts = place['daily']['data']
print(len(forecasts))
for forecast in forecasts:
    if forecast['temperatureHigh'] > 84:
        print("The high temperature is " + str(forecast['temperatureHigh']) + "°F. It is hot." )
    elif forecast['temperatureHigh'] > 69:
        print("The high temperature is " + str(forecast['temperatureHigh']) + "°F. It is warm." )
    else:
        print("The high temperature is " + str(forecast['temperatureHigh']) + "°F. It is cold." )
# Out:
# 8
# The high temperature is 80.79°F. It is warm.
# The high temperature is 81.57°F. It is warm.
# The high temperature is 84.15°F. It is hot.
# The high temperature is 81.85°F. It is warm.
# The high temperature is 86.43°F. It is hot.
# The high temperature is 85.46°F. It is hot.
# The high temperature is 81.41°F. It is warm.
# The high temperature is 81.69°F. It is warm.

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
forecasts = place['daily']['data']
temp_high = []
for forecast in forecasts:
    temp_high.append(forecast['temperatureHigh'])
print(temp_high)

if forecast['temperatureHigh'] == max(temp_high):
    print(forecast['time'])
# Out:
# [80.79, 81.57, 84.15, 81.85, 86.43, 85.46, 81.41, 81.69]

# %%
from datetime import datetime
time = int(forecast['time'])
print("The hottest day next week will be " + datetime.utcfromtimestamp(time).strftime('%Y-%m-%d') +  ". The high temperature that day will be", max(temp_high),"°F.")
# Out:
# The hottest day next week will be 2019-06-16. The high temperature that day will be 86.43 °F.

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
latitute = '25.7617'
longtitute = '-80.1918'
api_key = 'ab9931a51f9f9e64b02fdaf244d7a5fc'
url = 'https://api.darksky.net/forecast/' + api_key + "/" + latitute + "," + longtitute
response = requests.get(url)

# %%
place = response.json()

# %%
place
# Out:
# {'latitude': 25.7617,
#  'longitude': -80.1918,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560131667,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'nearestStormDistance': 40,
#   'nearestStormBearing': 334,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 78.67,
#   'apparentTemperature': 82.08,
#   'dewPoint': 75.06,
#   'humidity': 0.89,
#   'pressure': 1016.28,
#   'windSpeed': 1.5,
#   'windGust': 3.02,
#   'windBearing': 176,
#   'cloudCover': 0.07,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 299.66},
#  'minutely': {'summary': 'Humid for the hour.',
#   'icon': 'clear-night',
#   'data': [{'time': 1560131640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560131700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560131760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560131820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560131880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560131940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560132960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133020, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133080, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133920, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560133980, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134040, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134100, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134160, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134220, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134280, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134340, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134400, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134460, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134520, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134580, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560134940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560135000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560135060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560135120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560135180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560135240, 'precipIntensity': 0, 'precipProbability': 0}]},
#  'hourly': {'summary': 'Rain tomorrow afternoon.',
#   'icon': 'rain',
#   'data': [{'time': 1560128400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.16,
#     'apparentTemperature': 83.12,
#     'dewPoint': 74.9,
#     'humidity': 0.87,
#     'pressure': 1016.18,
#     'windSpeed': 2,
#     'windGust': 3.56,
#     'windBearing': 165,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.48},
#    {'time': 1560132000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.62,
#     'apparentTemperature': 81.97,
#     'dewPoint': 75.08,
#     'humidity': 0.89,
#     'pressure': 1016.29,
#     'windSpeed': 1.45,
#     'windGust': 2.96,
#     'windBearing': 178,
#     'cloudCover': 0.04,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.67},
#    {'time': 1560135600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.59,
#     'apparentTemperature': 81.93,
#     'dewPoint': 75.28,
#     'humidity': 0.9,
#     'pressure': 1016.58,
#     'windSpeed': 2.04,
#     'windGust': 3.28,
#     'windBearing': 186,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.83},
#    {'time': 1560139200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.35,
#     'apparentTemperature': 86.05,
#     'dewPoint': 75.74,
#     'humidity': 0.86,
#     'pressure': 1016.47,
#     'windSpeed': 4.8,
#     'windGust': 6.5,
#     'windBearing': 184,
#     'cloudCover': 0.14,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.78},
#    {'time': 1560142800,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0021,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 81.01,
#     'apparentTemperature': 87.35,
#     'dewPoint': 75.88,
#     'humidity': 0.84,
#     'pressure': 1016.46,
#     'windSpeed': 6.04,
#     'windGust': 7.92,
#     'windBearing': 176,
#     'cloudCover': 0.22,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.51},
#    {'time': 1560146400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0041,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 80.34,
#     'apparentTemperature': 86.07,
#     'dewPoint': 75.78,
#     'humidity': 0.86,
#     'pressure': 1016.26,
#     'windSpeed': 6.3,
#     'windGust': 7.88,
#     'windBearing': 195,
#     'cloudCover': 0.24,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.43},
#    {'time': 1560150000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0041,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 80.1,
#     'apparentTemperature': 85.58,
#     'dewPoint': 75.69,
#     'humidity': 0.86,
#     'pressure': 1015.89,
#     'windSpeed': 6.25,
#     'windGust': 8.19,
#     'windBearing': 191,
#     'cloudCover': 0.35,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.61},
#    {'time': 1560153600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0073,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 80.23,
#     'apparentTemperature': 85.84,
#     'dewPoint': 75.72,
#     'humidity': 0.86,
#     'pressure': 1015.5,
#     'windSpeed': 6.81,
#     'windGust': 9.66,
#     'windBearing': 177,
#     'cloudCover': 0.42,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.86},
#    {'time': 1560157200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0183,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 80.5,
#     'apparentTemperature': 86.05,
#     'dewPoint': 75.36,
#     'humidity': 0.84,
#     'pressure': 1015.43,
#     'windSpeed': 7.23,
#     'windGust': 9.78,
#     'windBearing': 167,
#     'cloudCover': 0.3,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 300.18},
#    {'time': 1560160800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0065,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 81.33,
#     'apparentTemperature': 87.66,
#     'dewPoint': 75.36,
#     'humidity': 0.82,
#     'pressure': 1015.57,
#     'windSpeed': 7.22,
#     'windGust': 10.31,
#     'windBearing': 171,
#     'cloudCover': 0.42,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 300.37},
#    {'time': 1560164400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0019,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 81.95,
#     'apparentTemperature': 88.58,
#     'dewPoint': 75.01,
#     'humidity': 0.8,
#     'pressure': 1016,
#     'windSpeed': 7.84,
#     'windGust': 10.59,
#     'windBearing': 165,
#     'cloudCover': 0.58,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 300.48},
#    {'time': 1560168000,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 83.25,
#     'apparentTemperature': 90.71,
#     'dewPoint': 74.91,
#     'humidity': 0.76,
#     'pressure': 1016.52,
#     'windSpeed': 8.05,
#     'windGust': 10.6,
#     'windBearing': 165,
#     'cloudCover': 0.6,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 300.81},
#    {'time': 1560171600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0014,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 84.77,
#     'apparentTemperature': 92.73,
#     'dewPoint': 74.51,
#     'humidity': 0.72,
#     'pressure': 1016.99,
#     'windSpeed': 9.07,
#     'windGust': 11.73,
#     'windBearing': 166,
#     'cloudCover': 0.51,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 301.82},
#    {'time': 1560175200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0014,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 86.78,
#     'apparentTemperature': 95.35,
#     'dewPoint': 74.23,
#     'humidity': 0.66,
#     'pressure': 1017.29,
#     'windSpeed': 8.54,
#     'windGust': 10.46,
#     'windBearing': 166,
#     'cloudCover': 0.44,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 302.92},
#    {'time': 1560178800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.004,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 88.03,
#     'apparentTemperature': 96.82,
#     'dewPoint': 74,
#     'humidity': 0.63,
#     'pressure': 1017.52,
#     'windSpeed': 9.06,
#     'windGust': 11.03,
#     'windBearing': 163,
#     'cloudCover': 0.43,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 303.1},
#    {'time': 1560182400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0101,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 89.43,
#     'apparentTemperature': 98.1,
#     'dewPoint': 73.45,
#     'humidity': 0.6,
#     'pressure': 1017.4,
#     'windSpeed': 8.91,
#     'windGust': 9,
#     'windBearing': 174,
#     'cloudCover': 0.36,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 301.49},
#    {'time': 1560186000,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0353,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'temperature': 89.43,
#     'apparentTemperature': 98.04,
#     'dewPoint': 73.39,
#     'humidity': 0.59,
#     'pressure': 1017.34,
#     'windSpeed': 9.17,
#     'windGust': 9.5,
#     'windBearing': 178,
#     'cloudCover': 0.55,
#     'uvIndex': 8,
#     'visibility': 8.33,
#     'ozone': 298.86},
#    {'time': 1560189600,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0605,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'temperature': 89.2,
#     'apparentTemperature': 97.72,
#     'dewPoint': 73.37,
#     'humidity': 0.6,
#     'pressure': 1017.14,
#     'windSpeed': 9.21,
#     'windGust': 9.77,
#     'windBearing': 181,
#     'cloudCover': 0.69,
#     'uvIndex': 7,
#     'visibility': 6.38,
#     'ozone': 296.6},
#    {'time': 1560193200,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0548,
#     'precipProbability': 0.21,
#     'precipType': 'rain',
#     'temperature': 89.2,
#     'apparentTemperature': 97.71,
#     'dewPoint': 73.37,
#     'humidity': 0.6,
#     'pressure': 1016.78,
#     'windSpeed': 8.87,
#     'windGust': 9.48,
#     'windBearing': 183,
#     'cloudCover': 0.72,
#     'uvIndex': 6,
#     'visibility': 7.43,
#     'ozone': 295.11},
#    {'time': 1560196800,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0366,
#     'precipProbability': 0.16,
#     'precipType': 'rain',
#     'temperature': 88.71,
#     'apparentTemperature': 97.11,
#     'dewPoint': 73.4,
#     'humidity': 0.61,
#     'pressure': 1016.28,
#     'windSpeed': 8.3,
#     'windGust': 8.91,
#     'windBearing': 184,
#     'cloudCover': 0.69,
#     'uvIndex': 5,
#     'visibility': 9.97,
#     'ozone': 293.97},
#    {'time': 1560200400,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0252,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 88.16,
#     'apparentTemperature': 96.47,
#     'dewPoint': 73.49,
#     'humidity': 0.62,
#     'pressure': 1015.9,
#     'windSpeed': 7.76,
#     'windGust': 8.45,
#     'windBearing': 185,
#     'cloudCover': 0.66,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 292.98},
#    {'time': 1560204000,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0195,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 87.4,
#     'apparentTemperature': 95.6,
#     'dewPoint': 73.63,
#     'humidity': 0.64,
#     'pressure': 1015.7,
#     'windSpeed': 7.34,
#     'windGust': 8.28,
#     'windBearing': 182,
#     'cloudCover': 0.62,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 292.04},
#    {'time': 1560207600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0147,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 86.46,
#     'apparentTemperature': 94.46,
#     'dewPoint': 73.77,
#     'humidity': 0.66,
#     'pressure': 1015.59,
#     'windSpeed': 6.93,
#     'windGust': 8.22,
#     'windBearing': 177,
#     'cloudCover': 0.58,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.4},
#    {'time': 1560211200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0102,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 85.55,
#     'apparentTemperature': 93.34,
#     'dewPoint': 73.94,
#     'humidity': 0.68,
#     'pressure': 1015.69,
#     'windSpeed': 6.59,
#     'windGust': 8.06,
#     'windBearing': 175,
#     'cloudCover': 0.52,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.07},
#    {'time': 1560214800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0046,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 84.76,
#     'apparentTemperature': 92.38,
#     'dewPoint': 74.12,
#     'humidity': 0.71,
#     'pressure': 1016.14,
#     'windSpeed': 6.34,
#     'windGust': 7.67,
#     'windBearing': 176,
#     'cloudCover': 0.4,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.54},
#    {'time': 1560218400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0008,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 83.96,
#     'apparentTemperature': 91.31,
#     'dewPoint': 74.28,
#     'humidity': 0.73,
#     'pressure': 1016.78,
#     'windSpeed': 6.1,
#     'windGust': 7.22,
#     'windBearing': 179,
#     'cloudCover': 0.24,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 292.4},
#    {'time': 1560222000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 83.13,
#     'apparentTemperature': 90.08,
#     'dewPoint': 74.35,
#     'humidity': 0.75,
#     'pressure': 1017.1,
#     'windSpeed': 5.85,
#     'windGust': 6.78,
#     'windBearing': 186,
#     'cloudCover': 0.13,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 292.8},
#    {'time': 1560225600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 82.43,
#     'apparentTemperature': 88.92,
#     'dewPoint': 74.31,
#     'humidity': 0.77,
#     'pressure': 1016.87,
#     'windSpeed': 5.61,
#     'windGust': 6.33,
#     'windBearing': 195,
#     'cloudCover': 0.16,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.91},
#    {'time': 1560229200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 81.92,
#     'apparentTemperature': 87.96,
#     'dewPoint': 74.13,
#     'humidity': 0.77,
#     'pressure': 1016.38,
#     'windSpeed': 5.36,
#     'windGust': 5.83,
#     'windBearing': 206,
#     'cloudCover': 0.23,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 290.58},
#    {'time': 1560232800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 81.45,
#     'apparentTemperature': 87.06,
#     'dewPoint': 73.94,
#     'humidity': 0.78,
#     'pressure': 1015.99,
#     'windSpeed': 5.08,
#     'windGust': 5.37,
#     'windBearing': 215,
#     'cloudCover': 0.29,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.5},
#    {'time': 1560236400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 81.07,
#     'apparentTemperature': 86.3,
#     'dewPoint': 73.72,
#     'humidity': 0.78,
#     'pressure': 1015.86,
#     'windSpeed': 4.61,
#     'windGust': 4.88,
#     'windBearing': 218,
#     'cloudCover': 0.34,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.27},
#    {'time': 1560240000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0006,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 80.3,
#     'apparentTemperature': 84.83,
#     'dewPoint': 73.46,
#     'humidity': 0.8,
#     'pressure': 1015.85,
#     'windSpeed': 4.06,
#     'windGust': 4.34,
#     'windBearing': 220,
#     'cloudCover': 0.4,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.3},
#    {'time': 1560243600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 80.01,
#     'apparentTemperature': 84.24,
#     'dewPoint': 73.25,
#     'humidity': 0.8,
#     'pressure': 1015.92,
#     'windSpeed': 3.69,
#     'windGust': 3.97,
#     'windBearing': 217,
#     'cloudCover': 0.44,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.69},
#    {'time': 1560247200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0013,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 80.11,
#     'apparentTemperature': 84.37,
#     'dewPoint': 73.11,
#     'humidity': 0.79,
#     'pressure': 1016.15,
#     'windSpeed': 3.58,
#     'windGust': 3.85,
#     'windBearing': 211,
#     'cloudCover': 0.45,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 290.24},
#    {'time': 1560250800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0038,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 80.76,
#     'apparentTemperature': 85.44,
#     'dewPoint': 73.02,
#     'humidity': 0.77,
#     'pressure': 1016.51,
#     'windSpeed': 3.64,
#     'windGust': 4.07,
#     'windBearing': 203,
#     'cloudCover': 0.44,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.15},
#    {'time': 1560254400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0062,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 82.15,
#     'apparentTemperature': 87.62,
#     'dewPoint': 72.98,
#     'humidity': 0.74,
#     'pressure': 1016.83,
#     'windSpeed': 3.86,
#     'windGust': 4.45,
#     'windBearing': 194,
#     'cloudCover': 0.43,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 291.83},
#    {'time': 1560258000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0037,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 84.5,
#     'apparentTemperature': 91.04,
#     'dewPoint': 72.96,
#     'humidity': 0.68,
#     'pressure': 1017.08,
#     'windSpeed': 4.2,
#     'windGust': 5.06,
#     'windBearing': 187,
#     'cloudCover': 0.52,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 292.3},
#    {'time': 1560261600,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0007,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 86.72,
#     'apparentTemperature': 94.01,
#     'dewPoint': 72.92,
#     'humidity': 0.64,
#     'pressure': 1017.32,
#     'windSpeed': 4.61,
#     'windGust': 5.78,
#     'windBearing': 179,
#     'cloudCover': 0.64,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 292.64},
#    {'time': 1560265200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 88.4,
#     'apparentTemperature': 96.14,
#     'dewPoint': 72.84,
#     'humidity': 0.6,
#     'pressure': 1017.4,
#     'windSpeed': 5.11,
#     'windGust': 6.36,
#     'windBearing': 172,
#     'cloudCover': 0.72,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 292.65},
#    {'time': 1560268800,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 89.74,
#     'apparentTemperature': 97.61,
#     'dewPoint': 72.6,
#     'humidity': 0.57,
#     'pressure': 1017.25,
#     'windSpeed': 5.84,
#     'windGust': 6.54,
#     'windBearing': 163,
#     'cloudCover': 0.71,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 292.47},
#    {'time': 1560272400,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 91,
#     'apparentTemperature': 98.92,
#     'dewPoint': 72.31,
#     'humidity': 0.55,
#     'pressure': 1016.95,
#     'windSpeed': 6.75,
#     'windGust': 6.81,
#     'windBearing': 154,
#     'cloudCover': 0.71,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 292.1},
#    {'time': 1560276000,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 91.47,
#     'apparentTemperature': 99.48,
#     'dewPoint': 72.27,
#     'humidity': 0.54,
#     'pressure': 1016.58,
#     'windSpeed': 7.7,
#     'windGust': 7.76,
#     'windBearing': 147,
#     'cloudCover': 0.7,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 291.72},
#    {'time': 1560279600,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0006,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 91.32,
#     'apparentTemperature': 99.72,
#     'dewPoint': 72.7,
#     'humidity': 0.55,
#     'pressure': 1016.02,
#     'windSpeed': 8.76,
#     'windGust': 9.18,
#     'windBearing': 148,
#     'cloudCover': 0.66,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 291.48},
#    {'time': 1560283200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 90.25,
#     'apparentTemperature': 99.08,
#     'dewPoint': 73.38,
#     'humidity': 0.58,
#     'pressure': 1015.38,
#     'windSpeed': 9.86,
#     'windGust': 11.67,
#     'windBearing': 152,
#     'cloudCover': 0.6,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 291.29},
#    {'time': 1560286800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0024,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 88.91,
#     'apparentTemperature': 97.81,
#     'dewPoint': 73.83,
#     'humidity': 0.61,
#     'pressure': 1014.95,
#     'windSpeed': 10.64,
#     'windGust': 13.49,
#     'windBearing': 156,
#     'cloudCover': 0.54,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 291.57},
#    {'time': 1560290400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0014,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 87.76,
#     'apparentTemperature': 96.37,
#     'dewPoint': 73.91,
#     'humidity': 0.64,
#     'pressure': 1014.89,
#     'windSpeed': 11.07,
#     'windGust': 14.19,
#     'windBearing': 160,
#     'cloudCover': 0.46,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 292.6},
#    {'time': 1560294000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 86.61,
#     'apparentTemperature': 94.71,
#     'dewPoint': 73.81,
#     'humidity': 0.66,
#     'pressure': 1015.06,
#     'windSpeed': 11.21,
#     'windGust': 14.28,
#     'windBearing': 165,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294.05},
#    {'time': 1560297600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 85.78,
#     'apparentTemperature': 93.51,
#     'dewPoint': 73.76,
#     'humidity': 0.68,
#     'pressure': 1015.31,
#     'windSpeed': 10.97,
#     'windGust': 13.91,
#     'windBearing': 170,
#     'cloudCover': 0.31,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 295.63},
#    {'time': 1560301200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 84.93,
#     'apparentTemperature': 92.39,
#     'dewPoint': 73.85,
#     'humidity': 0.7,
#     'pressure': 1015.71,
#     'windSpeed': 10.18,
#     'windGust': 12.9,
#     'windBearing': 176,
#     'cloudCover': 0.28,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.4}]},
#  'daily': {'summary': 'Light rain tomorrow through next Sunday, with high temperatures rising to 91°F on Tuesday.',
#   'icon': 'rain',
#   'data': [{'time': 1560052800,
#     'summary': 'Humid throughout the day and mostly cloudy until evening.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560076214,
#     'sunsetTime': 1560125565,
#     'moonPhase': 0.23,
#     'precipIntensity': 0.0008,
#     'precipIntensityMax': 0.0061,
#     'precipIntensityMaxTime': 1560103200,
#     'precipProbability': 0.87,
#     'precipType': 'rain',
#     'temperatureHigh': 88.09,
#     'temperatureHighTime': 1560096000,
#     'temperatureLow': 78.59,
#     'temperatureLowTime': 1560135600,
#     'apparentTemperatureHigh': 99.34,
#     'apparentTemperatureHighTime': 1560096000,
#     'apparentTemperatureLow': 81.93,
#     'apparentTemperatureLowTime': 1560135600,
#     'dewPoint': 76.07,
#     'humidity': 0.84,
#     'pressure': 1015.4,
#     'windSpeed': 4.1,
#     'windGust': 11.23,
#     'windGustTime': 1560096000,
#     'windBearing': 169,
#     'cloudCover': 0.42,
#     'uvIndex': 6,
#     'uvIndexTime': 1560096000,
#     'visibility': 9.62,
#     'ozone': 296.58,
#     'temperatureMin': 78.59,
#     'temperatureMinTime': 1560135600,
#     'temperatureMax': 88.09,
#     'temperatureMaxTime': 1560096000,
#     'apparentTemperatureMin': 81.93,
#     'apparentTemperatureMinTime': 1560135600,
#     'apparentTemperatureMax': 99.34,
#     'apparentTemperatureMaxTime': 1560096000},
#    {'time': 1560139200,
#     'summary': 'Rain in the afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560162614,
#     'sunsetTime': 1560211987,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.0135,
#     'precipIntensityMax': 0.0605,
#     'precipIntensityMaxTime': 1560189600,
#     'precipProbability': 0.66,
#     'precipType': 'rain',
#     'temperatureHigh': 89.43,
#     'temperatureHighTime': 1560186000,
#     'temperatureLow': 80.01,
#     'temperatureLowTime': 1560243600,
#     'apparentTemperatureHigh': 98.1,
#     'apparentTemperatureHighTime': 1560182400,
#     'apparentTemperatureLow': 84.24,
#     'apparentTemperatureLowTime': 1560243600,
#     'dewPoint': 74.45,
#     'humidity': 0.72,
#     'pressure': 1016.41,
#     'windSpeed': 7.36,
#     'windGust': 11.73,
#     'windGustTime': 1560171600,
#     'windBearing': 176,
#     'cloudCover': 0.45,
#     'uvIndex': 8,
#     'uvIndexTime': 1560182400,
#     'visibility': 9.67,
#     'ozone': 297.42,
#     'temperatureMin': 80.1,
#     'temperatureMinTime': 1560150000,
#     'temperatureMax': 89.43,
#     'temperatureMaxTime': 1560186000,
#     'apparentTemperatureMin': 85.58,
#     'apparentTemperatureMinTime': 1560150000,
#     'apparentTemperatureMax': 98.1,
#     'apparentTemperatureMaxTime': 1560182400},
#    {'time': 1560225600,
#     'summary': 'Humid and partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560249015,
#     'sunsetTime': 1560298409,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0019,
#     'precipIntensityMax': 0.0119,
#     'precipIntensityMaxTime': 1560308400,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'temperatureHigh': 91.47,
#     'temperatureHighTime': 1560276000,
#     'temperatureLow': 79.77,
#     'temperatureLowTime': 1560326400,
#     'apparentTemperatureHigh': 99.72,
#     'apparentTemperatureHighTime': 1560279600,
#     'apparentTemperatureLow': 83.76,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 73.38,
#     'humidity': 0.69,
#     'pressure': 1016.21,
#     'windSpeed': 6.31,
#     'windGust': 14.28,
#     'windGustTime': 1560294000,
#     'windBearing': 176,
#     'cloudCover': 0.45,
#     'uvIndex': 7,
#     'uvIndexTime': 1560272400,
#     'visibility': 10,
#     'ozone': 292.57,
#     'temperatureMin': 80.01,
#     'temperatureMinTime': 1560243600,
#     'temperatureMax': 91.47,
#     'temperatureMaxTime': 1560276000,
#     'apparentTemperatureMin': 84.24,
#     'apparentTemperatureMinTime': 1560243600,
#     'apparentTemperatureMax': 99.72,
#     'apparentTemperatureMaxTime': 1560279600},
#    {'time': 1560312000,
#     'summary': 'Humid and partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560335417,
#     'sunsetTime': 1560384830,
#     'moonPhase': 0.34,
#     'precipIntensity': 0.0024,
#     'precipIntensityMax': 0.0122,
#     'precipIntensityMaxTime': 1560394800,
#     'precipProbability': 0.32,
#     'precipType': 'rain',
#     'temperatureHigh': 91.16,
#     'temperatureHighTime': 1560366000,
#     'temperatureLow': 81.97,
#     'temperatureLowTime': 1560412800,
#     'apparentTemperatureHigh': 99.83,
#     'apparentTemperatureHighTime': 1560366000,
#     'apparentTemperatureLow': 88.14,
#     'apparentTemperatureLowTime': 1560412800,
#     'dewPoint': 73.26,
#     'humidity': 0.69,
#     'pressure': 1015.97,
#     'windSpeed': 7.12,
#     'windGust': 14.17,
#     'windGustTime': 1560384000,
#     'windBearing': 173,
#     'cloudCover': 0.34,
#     'uvIndex': 9,
#     'uvIndexTime': 1560358800,
#     'visibility': 10,
#     'ozone': 301.91,
#     'temperatureMin': 79.77,
#     'temperatureMinTime': 1560326400,
#     'temperatureMax': 91.16,
#     'temperatureMaxTime': 1560366000,
#     'apparentTemperatureMin': 83.76,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 99.83,
#     'apparentTemperatureMaxTime': 1560366000},
#    {'time': 1560398400,
#     'summary': 'Humid throughout the day and partly cloudy starting in the afternoon.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560421821,
#     'sunsetTime': 1560471250,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.011,
#     'precipIntensityMax': 0.0371,
#     'precipIntensityMaxTime': 1560470400,
#     'precipProbability': 0.7,
#     'precipType': 'rain',
#     'temperatureHigh': 91.47,
#     'temperatureHighTime': 1560452400,
#     'temperatureLow': 81.16,
#     'temperatureLowTime': 1560499200,
#     'apparentTemperatureHigh': 100.8,
#     'apparentTemperatureHighTime': 1560456000,
#     'apparentTemperatureLow': 85.86,
#     'apparentTemperatureLowTime': 1560502800,
#     'dewPoint': 73.48,
#     'humidity': 0.67,
#     'pressure': 1016.62,
#     'windSpeed': 7.35,
#     'windGust': 13.19,
#     'windGustTime': 1560466800,
#     'windBearing': 190,
#     'cloudCover': 0.24,
#     'uvIndex': 11,
#     'uvIndexTime': 1560445200,
#     'visibility': 9.25,
#     'ozone': 285.08,
#     'temperatureMin': 81.97,
#     'temperatureMinTime': 1560412800,
#     'temperatureMax': 91.47,
#     'temperatureMaxTime': 1560452400,
#     'apparentTemperatureMin': 88.14,
#     'apparentTemperatureMinTime': 1560412800,
#     'apparentTemperatureMax': 100.8,
#     'apparentTemperatureMaxTime': 1560456000},
#    {'time': 1560484800,
#     'summary': 'Humid and mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560508225,
#     'sunsetTime': 1560557669,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0058,
#     'precipIntensityMax': 0.0308,
#     'precipIntensityMaxTime': 1560567600,
#     'precipProbability': 0.56,
#     'precipType': 'rain',
#     'temperatureHigh': 91.29,
#     'temperatureHighTime': 1560538800,
#     'temperatureLow': 81.48,
#     'temperatureLowTime': 1560582000,
#     'apparentTemperatureHigh': 98.61,
#     'apparentTemperatureHighTime': 1560538800,
#     'apparentTemperatureLow': 85.95,
#     'apparentTemperatureLowTime': 1560582000,
#     'dewPoint': 72.25,
#     'humidity': 0.65,
#     'pressure': 1017.78,
#     'windSpeed': 5.4,
#     'windGust': 12.69,
#     'windGustTime': 1560553200,
#     'windBearing': 161,
#     'cloudCover': 0.69,
#     'uvIndex': 8,
#     'uvIndexTime': 1560528000,
#     'visibility': 9.6,
#     'ozone': 279.53,
#     'temperatureMin': 81.16,
#     'temperatureMinTime': 1560499200,
#     'temperatureMax': 91.29,
#     'temperatureMaxTime': 1560538800,
#     'apparentTemperatureMin': 85.86,
#     'apparentTemperatureMinTime': 1560502800,
#     'apparentTemperatureMax': 98.61,
#     'apparentTemperatureMaxTime': 1560538800},
#    {'time': 1560571200,
#     'summary': 'Humid and overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560594631,
#     'sunsetTime': 1560644088,
#     'moonPhase': 0.45,
#     'precipIntensity': 0.0054,
#     'precipIntensityMax': 0.0215,
#     'precipIntensityMaxTime': 1560571200,
#     'precipProbability': 0.84,
#     'precipType': 'rain',
#     'temperatureHigh': 89.1,
#     'temperatureHighTime': 1560618000,
#     'temperatureLow': 81.98,
#     'temperatureLowTime': 1560682800,
#     'apparentTemperatureHigh': 98.06,
#     'apparentTemperatureHighTime': 1560618000,
#     'apparentTemperatureLow': 87.02,
#     'apparentTemperatureLowTime': 1560682800,
#     'dewPoint': 73.14,
#     'humidity': 0.69,
#     'pressure': 1018.28,
#     'windSpeed': 9.25,
#     'windGust': 18.22,
#     'windGustTime': 1560654000,
#     'windBearing': 104,
#     'cloudCover': 1,
#     'uvIndex': 5,
#     'uvIndexTime': 1560614400,
#     'visibility': 9.36,
#     'ozone': 281.41,
#     'temperatureMin': 81.48,
#     'temperatureMinTime': 1560582000,
#     'temperatureMax': 89.1,
#     'temperatureMaxTime': 1560618000,
#     'apparentTemperatureMin': 85.95,
#     'apparentTemperatureMinTime': 1560582000,
#     'apparentTemperatureMax': 98.06,
#     'apparentTemperatureMaxTime': 1560618000},
#    {'time': 1560657600,
#     'summary': 'Rain in the morning and afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560681038,
#     'sunsetTime': 1560730505,
#     'moonPhase': 0.48,
#     'precipIntensity': 0.0185,
#     'precipIntensityMax': 0.0583,
#     'precipIntensityMaxTime': 1560686400,
#     'precipProbability': 0.92,
#     'precipType': 'rain',
#     'temperatureHigh': 88.57,
#     'temperatureHighTime': 1560704400,
#     'temperatureLow': 81.53,
#     'temperatureLowTime': 1560758400,
#     'apparentTemperatureHigh': 94.59,
#     'apparentTemperatureHighTime': 1560704400,
#     'apparentTemperatureLow': 86.32,
#     'apparentTemperatureLowTime': 1560758400,
#     'dewPoint': 71.88,
#     'humidity': 0.66,
#     'pressure': 1017.69,
#     'windSpeed': 10.27,
#     'windGust': 18.14,
#     'windGustTime': 1560657600,
#     'windBearing': 119,
#     'cloudCover': 1,
#     'uvIndex': 5,
#     'uvIndexTime': 1560700800,
#     'visibility': 8.85,
#     'ozone': 293.89,
#     'temperatureMin': 81.98,
#     'temperatureMinTime': 1560682800,
#     'temperatureMax': 88.57,
#     'temperatureMaxTime': 1560704400,
#     'apparentTemperatureMin': 87.02,
#     'apparentTemperatureMinTime': 1560682800,
#     'apparentTemperatureMax': 94.59,
#     'apparentTemperatureMaxTime': 1560704400}]},
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 2.805,
#   'units': 'us'},
#  'offset': -4}

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
latitute = '25.7617'
longtitute = '-80.1918'
api_key = 'ab9931a51f9f9e64b02fdaf244d7a5fc'
url = 'https://api.darksky.net/forecast/' + api_key + "/" + latitute + "," + longtitute
response = requests.get(url)

# %%
place = response.json()
forecasts_hour = place['hourly']['data']
count_85 = 0
for forecast in forecasts_hour:
    if forecast['temperature'] > 85:
        count_85 = count_85 + 1
print(count_85)
# Out:
# 22

# %%
print("About", round(100 * count_85 / len(forecasts_hour), 2), "percent of the time for the next", len(forecasts_hour), "hours, the temperature is above 85 degress.")
# Out:
# About 44.9 percent of the time for the next 49 hours, the temperature is above 85 degress.

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
import time
import datetime

year = 2012
month = 12
date = 25
d = datetime.date(year, month, date)
unixtime = round(time.mktime(d.timetuple()))
print(unixtime)

latitute = '40.7128'
longtitute = '-74.0060'
api_key = 'ab9931a51f9f9e64b02fdaf244d7a5fc'
url = 'https://api.darksky.net/forecast/' + api_key + "/" + latitute + "," + longtitute + "," + str(unixtime)
response = requests.get(url)
# Out:
# 1356411600

# %%
place = response.json()
place.keys()
high_temp = place['daily']['data'][0]['temperatureHigh']
low_temp = place['daily']['data'][0]['temperatureLow']

# %%
print("The high temperature in Central Park on Christmas Day", year, "is", high_temp, "degrees, the low temperature is", low_temp, "degrees." )
# Out:
# The high temperature in Central Park on Christmas Day 2012 is 40.75 degrees, the low temperature is 28.33 degrees.

# %%
year = 2005
d = datetime.date(year, month, date)
unixtime = round(time.mktime(d.timetuple()))
print(unixtime)

latitute = '40.7128'
longtitute = '-74.0060'
api_key = 'ab9931a51f9f9e64b02fdaf244d7a5fc'
url = 'https://api.darksky.net/forecast/' + api_key + "/" + latitute + "," + longtitute + "," + str(unixtime)
response = requests.get(url)
place = response.json()
place.keys()
high_temp = place['daily']['data'][0]['temperatureHigh']
low_temp = place['daily']['data'][0]['temperatureLow']
print("The high temperature in Central Park on Christmas Day", year, "is", high_temp, "degrees, the low temperature is", low_temp, "degrees." )
# Out:
# 1135486800
# The high temperature in Central Park on Christmas Day 2005 is 46.25 degrees, the low temperature is 45.98 degrees.

# %%
year = 2007
d = datetime.date(year, month, date)
unixtime = round(time.mktime(d.timetuple()))
print(unixtime)

latitute = '40.7128'
longtitute = '-74.0060'
api_key = 'ab9931a51f9f9e64b02fdaf244d7a5fc'
url = 'https://api.darksky.net/forecast/' + api_key + "/" + latitute + "," + longtitute + "," + str(unixtime)
response = requests.get(url)
place = response.json()
place.keys()
high_temp = place['daily']['data'][0]['temperatureHigh']
low_temp = place['daily']['data'][0]['temperatureLow']
print("The high temperature in Central Park on Christmas Day", year, "is", high_temp, "degrees, the low temperature is", low_temp, "degrees." )
# Out:
# 1198558800
# The high temperature in Central Park on Christmas Day 2007 is 43.02 degrees, the low temperature is 30.07 degrees.
