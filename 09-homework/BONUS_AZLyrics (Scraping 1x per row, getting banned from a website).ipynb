# %%
import pandas as pd
import requests

from bs4 import BeautifulSoup

# %%
url = "https://www.azlyrics.com/r/rem.html"
response = requests.get(url)
doc = BeautifulSoup(response.text)

# %%
rows = []
album = doc.find(id="listAlbum")
for song in album.find_all('a'):
    row = {}
    row['Title'] = song.text
    row['URL'] = song['href']
    rows.append(row)

# %%
rows
# Out:
# [{'Title': 'Radio Free Europe', 'URL': '../lyrics/rem/radiofreeeurope.html'},
#  {'Title': 'Pilgrimage', 'URL': '../lyrics/rem/pilgrimage.html'},
#  {'Title': 'Laughing', 'URL': '../lyrics/rem/laughing.html'},
#  {'Title': 'Talk About The Passion',
#   'URL': '../lyrics/rem/talkaboutthepassion.html'},
#  {'Title': 'Moral Kiosk', 'URL': '../lyrics/rem/moralkiosk.html'},
#  {'Title': 'Perfect Circle', 'URL': '../lyrics/rem/perfectcircle.html'},
#  {'Title': 'Catapult', 'URL': '../lyrics/rem/catapult.html'},
#  {'Title': 'Sitting Still', 'URL': '../lyrics/rem/sittingstill.html'},
#  {'Title': '9-9', 'URL': '../lyrics/rem/99.html'},
#  {'Title': 'Shaking Through', 'URL': '../lyrics/rem/shakingthrough.html'},
#  {'Title': 'We Walk', 'URL': '../lyrics/rem/wewalk.html'},
#  {'Title': 'West Of The Fields', 'URL': '../lyrics/rem/westofthefields.html'},
#  {'Title': 'Harborcoat', 'URL': '../lyrics/rem/harborcoat.html'},
#  {'Title': 'Seven Chinese Brothers',
#   'URL': '../lyrics/rem/sevenchinesebrothers.html'},
#  {'Title': 'So. Central Rain', 'URL': '../lyrics/rem/socentralrain.html'},
#  {'Title': 'Pretty Persuasion', 'URL': '../lyrics/rem/prettypersuasion.html'},
#  {'Title': 'Time After Time (AnnElise)',
#   'URL': '../lyrics/rem/timeaftertimeannelise.html'},
#  {'Title': 'Second Guessing', 'URL': '../lyrics/rem/secondguessing.html'},
#  {'Title': 'Letter Never Sent', 'URL': '../lyrics/rem/letterneversent.html'},
#  {'Title': 'Camera', 'URL': '../lyrics/rem/camera.html'},
#  {'Title': "(Don't Go Back To) Rockville",
#   'URL': '../lyrics/rem/dontgobacktorockville.html'},
#  {'Title': 'Little America', 'URL': '../lyrics/rem/littleamerica.html'},
#  {'Title': 'Wind Out', 'URL': '../lyrics/rem/windout.html'},
#  {'Title': 'Moon River', 'URL': '../lyrics/rem/moonriver.html'},
#  {'Title': 'Feeling Gravitys Pull',
#   'URL': '../lyrics/rem/feelinggravityspull.html'},
#  {'Title': 'Maps And Legends', 'URL': '../lyrics/rem/mapsandlegends.html'},
#  {'Title': 'Driver 8', 'URL': '../lyrics/rem/driver8.html'},
#  {'Title': 'Life And How To Live It',
#   'URL': '../lyrics/rem/lifeandhowtoliveit.html'},
#  {'Title': 'Old Man Kensey', 'URL': '../lyrics/rem/oldmankensey.html'},
#  {'Title': "Can't Get There From Here",
#   'URL': '../lyrics/rem/cantgettherefromhere.html'},
#  {'Title': 'Green Grow The Rushes',
#   'URL': '../lyrics/rem/greengrowtherushes.html'},
#  {'Title': 'Kohoutek', 'URL': '../lyrics/rem/kohoutek.html'},
#  {'Title': 'Auctioneer (Another Engine)',
#   'URL': '../lyrics/rem/auctioneeranotherengine.html'},
#  {'Title': 'Good Advices', 'URL': '../lyrics/rem/goodadvices.html'},
#  {'Title': 'Wendell Gee', 'URL': '../lyrics/rem/wendellgee.html'},
#  {'Title': 'Begin The Begin', 'URL': '../lyrics/rem/beginthebegin.html'},
#  {'Title': 'These Days', 'URL': '../lyrics/rem/thesedays.html'},
#  {'Title': 'Fall On Me', 'URL': '../lyrics/rem/fallonme.html'},
#  {'Title': 'Cuyahoga', 'URL': '../lyrics/rem/cuyahoga.html'},
#  {'Title': 'Hyena', 'URL': '../lyrics/rem/hyena.html'},
#  {'Title': 'Underneath The Bunker',
#   'URL': '../lyrics/rem/underneaththebunker.html'},
#  {'Title': 'The Flowers Of Guatemala',
#   'URL': '../lyrics/rem/theflowersofguatemala.html'},
#  {'Title': 'I Believe', 'URL': '../lyrics/rem/ibelieve.html'},
#  {'Title': 'What If We Give It Away?',
#   'URL': '../lyrics/rem/whatifwegiveitaway.html'},
#  {'Title': 'Just A Touch', 'URL': '../lyrics/rem/justatouch.html'},
#  {'Title': 'Swan Swan H', 'URL': '../lyrics/rem/swanswanh.html'},
#  {'Title': 'Superman', 'URL': '../lyrics/rem/superman.html'},
#  {'Title': 'Tired Of Singing Trouble',
#   'URL': '../lyrics/rem/tiredofsingingtrouble.html'},
#  {'Title': 'Toys In The Attic', 'URL': '../lyrics/rem/toysintheattic.html'},
#  {'Title': 'Dream (All I Have To Do)',
#   'URL': '../lyrics/rem/dreamallihavetodo.html'},
#  {'Title': 'Crazy', 'URL': '../lyrics/rem/crazy.html'},
#  {'Title': 'There She Goes Again',
#   'URL': '../lyrics/rem/thereshegoesagain.html'},
#  {'Title': 'Burning Down', 'URL': '../lyrics/rem/burningdown.html'},
#  {'Title': 'Voice Of Harold', 'URL': '../lyrics/rem/voiceofharold.html'},
#  {'Title': 'Burning Hell', 'URL': '../lyrics/rem/burninghell.html'},
#  {'Title': 'Toys In The Attic', 'URL': '../lyrics/rem/toysintheattic.html'},
#  {'Title': 'Windout', 'URL': '../lyrics/rem/windout.html'},
#  {'Title': 'Ages Of You', 'URL': '../lyrics/rem/agesofyou.html'},
#  {'Title': 'Pale Blue Eyes', 'URL': '../lyrics/rem/paleblueeyes.html'},
#  {'Title': 'Bandwagon', 'URL': '../lyrics/rem/bandwagon.html'},
#  {'Title': 'Femme Fatale', 'URL': '../lyrics/rem/femmefatale.html'},
#  {'Title': 'Walters Theme', 'URL': '../lyrics/rem/walterstheme.html'},
#  {'Title': 'King Of The Road', 'URL': '../lyrics/rem/kingoftheroad.html'},
#  {'Title': 'Wolves, Lower', 'URL': '../lyrics/rem/wolveslower.html'},
#  {'Title': 'Gardening At Night', 'URL': '../lyrics/rem/gardeningatnight.html'},
#  {'Title': 'Carnival Of Sorts (Box Cars)',
#   'URL': '../lyrics/rem/carnivalofsortsboxcars.html'},
#  {'Title': '1,000,000', 'URL': '../lyrics/rem/1000000.html'},
#  {'Title': 'Stumble', 'URL': '../lyrics/rem/stumble.html'},
#  {'Title': 'All The Right Friends',
#   'URL': '../lyrics/rem/alltherightfriends.html'},
#  {'Title': 'Finest Worksong', 'URL': '../lyrics/rem/finestworksong.html'},
#  {'Title': 'Welcome To The Occupation',
#   'URL': '../lyrics/rem/welcometotheoccupation.html'},
#  {'Title': 'Exhuming McCarthy', 'URL': '../lyrics/rem/exhumingmccarthy.html'},
#  {'Title': 'Disturbance At The Heron House',
#   'URL': '../lyrics/rem/disturbanceattheheronhouse.html'},
#  {'Title': 'Strange', 'URL': '../lyrics/rem/strange.html'},
#  {'Title': "It's The End Of The World As We Know It (And I Feel Fine)",
#   'URL': '../lyrics/rem/itstheendoftheworldasweknowitandifeelfine.html'},
#  {'Title': 'The One I Love', 'URL': '../lyrics/rem/theoneilove.html'},
#  {'Title': 'Fireplace', 'URL': '../lyrics/rem/fireplace.html'},
#  {'Title': "Lightnin' Hopkins", 'URL': '../lyrics/rem/lightninhopkins.html'},
#  {'Title': 'King Of Birds', 'URL': '../lyrics/rem/kingofbirds.html'},
#  {'Title': 'Oddfellows Local 151',
#   'URL': '../lyrics/rem/oddfellowslocal151.html'},
#  {'Title': 'Pop Song 89', 'URL': '../lyrics/rem/popsong89.html'},
#  {'Title': 'Get Up', 'URL': '../lyrics/rem/getup.html'},
#  {'Title': 'You Are The Everything',
#   'URL': '../lyrics/rem/youaretheeverything.html'},
#  {'Title': 'Stand', 'URL': '../lyrics/rem/stand.html'},
#  {'Title': 'World Leader Pretend',
#   'URL': '../lyrics/rem/worldleaderpretend.html'},
#  {'Title': 'The Wrong Child', 'URL': '../lyrics/rem/thewrongchild.html'},
#  {'Title': 'Orange Crush', 'URL': '../lyrics/rem/orangecrush.html'},
#  {'Title': 'Turn You Inside-Out',
#   'URL': '../lyrics/rem/turnyouinsideout.html'},
#  {'Title': 'Hairshirt', 'URL': '../lyrics/rem/hairshirt.html'},
#  {'Title': 'I Remember California',
#   'URL': '../lyrics/rem/iremembercalifornia.html'},
#  {'Title': 'Untitled', 'URL': '../lyrics/rem/untitled.html'},
#  {'Title': 'Radio Song', 'URL': '../lyrics/rem/radiosong.html'},
#  {'Title': 'Losing My Religion', 'URL': '../lyrics/rem/losingmyreligion.html'},
#  {'Title': 'Low', 'URL': '../lyrics/rem/low.html'},
#  {'Title': 'Near Wild Heaven', 'URL': '../lyrics/rem/nearwildheaven.html'},
#  {'Title': 'Shiny Happy People', 'URL': '../lyrics/rem/shinyhappypeople.html'},
#  {'Title': 'Belong', 'URL': '../lyrics/rem/belong.html'},
#  {'Title': 'Half A World Away', 'URL': '../lyrics/rem/halfaworldaway.html'},
#  {'Title': 'Texarkana', 'URL': '../lyrics/rem/texarkana.html'},
#  {'Title': 'Country Feedback', 'URL': '../lyrics/rem/countryfeedback.html'},
#  {'Title': 'Me In Honey', 'URL': '../lyrics/rem/meinhoney.html'},
#  {'Title': 'Drive', 'URL': '../lyrics/rem/drive.html'},
#  {'Title': 'Try Not To Breathe', 'URL': '../lyrics/rem/trynottobreathe.html'},
#  {'Title': 'The Sidewinder Sleeps Tonite',
#   'URL': '../lyrics/rem/thesidewindersleepstonite.html'},
#  {'Title': 'Everybody Hurts', 'URL': '../lyrics/rem/everybodyhurts.html'},
#  {'Title': 'Sweetness Follows', 'URL': '../lyrics/rem/sweetnessfollows.html'},
#  {'Title': 'Monty Got A Raw Deal',
#   'URL': '../lyrics/rem/montygotarawdeal.html'},
#  {'Title': 'Ignoreland', 'URL': '../lyrics/rem/ignoreland.html'},
#  {'Title': 'Star Me Kitten', 'URL': '../lyrics/rem/starmekitten.html'},
#  {'Title': 'Man On The Moon', 'URL': '../lyrics/rem/manonthemoon.html'},
#  {'Title': 'Nightswimming', 'URL': '../lyrics/rem/nightswimming.html'},
#  {'Title': 'Find The River', 'URL': '../lyrics/rem/findtheriver.html'},
#  {'Title': "What's The Frequency, Kenneth?",
#   'URL': '../lyrics/rem/whatsthefrequencykenneth.html'},
#  {'Title': 'Crush With Eyeliner',
#   'URL': '../lyrics/rem/crushwitheyeliner.html'},
#  {'Title': 'King Of Comedy', 'URL': '../lyrics/rem/kingofcomedy.html'},
#  {'Title': "I Don't Sleep, I Dream",
#   'URL': '../lyrics/rem/idontsleepidream.html'},
#  {'Title': 'Star 69', 'URL': '../lyrics/rem/star69.html'},
#  {'Title': 'Strange Currencies',
#   'URL': '../lyrics/rem/strangecurrencies.html'},
#  {'Title': 'Tongue', 'URL': '../lyrics/rem/tongue.html'},
#  {'Title': 'Bang And Blame', 'URL': '../lyrics/rem/bangandblame.html'},
#  {'Title': 'I Took Your Name', 'URL': '../lyrics/rem/itookyourname.html'},
#  {'Title': 'Let Me In', 'URL': '../lyrics/rem/letmein.html'},
#  {'Title': 'Circus Envy', 'URL': '../lyrics/rem/circusenvy.html'},
#  {'Title': 'You', 'URL': '../lyrics/rem/you.html'},
#  {'Title': 'How The West Was Won And Where It Got Us',
#   'URL': '../lyrics/rem/howthewestwaswonandwhereitgotus.html'},
#  {'Title': 'The Wake-Up Bomb', 'URL': '../lyrics/rem/thewakeupbomb.html'},
#  {'Title': 'New Test Leper', 'URL': '../lyrics/rem/newtestleper.html'},
#  {'Title': 'Undertow', 'URL': '../lyrics/rem/undertow.html'},
#  {'Title': 'E-Bow The Letter', 'URL': '../lyrics/rem/ebowtheletter.html'},
#  {'Title': 'Leave', 'URL': '../lyrics/rem/leave.html'},
#  {'Title': 'Departure', 'URL': '../lyrics/rem/departure.html'},
#  {'Title': 'Bittersweet Me', 'URL': '../lyrics/rem/bittersweetme.html'},
#  {'Title': 'Be Mine', 'URL': '../lyrics/rem/bemine.html'},
#  {'Title': 'Binky The Doormat', 'URL': '../lyrics/rem/binkythedoormat.html'},
#  {'Title': 'So Fast, So Numb', 'URL': '../lyrics/rem/sofastsonumb.html'},
#  {'Title': 'Low Desert', 'URL': '../lyrics/rem/lowdesert.html'},
#  {'Title': 'Electrolite', 'URL': '../lyrics/rem/electrolite.html'},
#  {'Title': 'Airportman', 'URL': '../lyrics/rem/airportman.html'},
#  {'Title': 'Lotus', 'URL': '../lyrics/rem/lotus.html'},
#  {'Title': 'Suspicion', 'URL': '../lyrics/rem/suspicion.html'},
#  {'Title': 'Hope', 'URL': '../lyrics/rem/hope.html'},
#  {'Title': 'At My Most Beautiful',
#   'URL': '../lyrics/rem/atmymostbeautiful.html'},
#  {'Title': 'The Apologist', 'URL': '../lyrics/rem/theapologist.html'},
#  {'Title': 'Sad Professor', 'URL': '../lyrics/rem/sadprofessor.html'},
#  {'Title': "You're In The Air", 'URL': '../lyrics/rem/youreintheair.html'},
#  {'Title': 'Walk Unafraid', 'URL': '../lyrics/rem/walkunafraid.html'},
#  {'Title': 'Why Not Smile', 'URL': '../lyrics/rem/whynotsmile.html'},
#  {'Title': 'Daysleeper', 'URL': '../lyrics/rem/daysleeper.html'},
#  {'Title': 'Diminished', 'URL': '../lyrics/rem/diminished.html'},
#  {'Title': 'Parakeet', 'URL': '../lyrics/rem/parakeet.html'},
#  {'Title': 'Falls To Climb', 'URL': '../lyrics/rem/fallstoclimb.html'},
#  {'Title': 'The Lifting', 'URL': '../lyrics/rem/thelifting.html'},
#  {'Title': "I've Been High", 'URL': '../lyrics/rem/ivebeenhigh.html'},
#  {'Title': "All The Way To Reno (You're Gonna Be A Star)",
#   'URL': '../lyrics/rem/allthewaytorenoyouregonnabeastar.html'},
#  {'Title': 'She Just Wants To Be',
#   'URL': '../lyrics/rem/shejustwantstobe.html'},
#  {'Title': 'Disappear', 'URL': '../lyrics/rem/disappear.html'},
#  {'Title': 'Saturn Return', 'URL': '../lyrics/rem/saturnreturn.html'},
#  {'Title': 'Beat A Drum', 'URL': '../lyrics/rem/beatadrum.html'},
#  {'Title': 'Imitation Of Life', 'URL': '../lyrics/rem/imitationoflife.html'},
#  {'Title': 'Summer Turns To High',
#   'URL': '../lyrics/rem/summerturnstohigh.html'},
#  {'Title': 'Chorus And The Ring',
#   'URL': '../lyrics/rem/chorusandthering.html'},
#  {'Title': "I'll Take The Rain", 'URL': '../lyrics/rem/illtaketherain.html'},
#  {'Title': 'Beach Ball', 'URL': '../lyrics/rem/beachball.html'},
#  {'Title': 'Leaving New York', 'URL': '../lyrics/rem/leavingnewyork.html'},
#  {'Title': 'Electron Blue', 'URL': '../lyrics/rem/electronblue.html'},
#  {'Title': 'The Outsiders', 'URL': '../lyrics/rem/theoutsiders.html'},
#  {'Title': 'Make It All Ok', 'URL': '../lyrics/rem/makeitallok.html'},
#  {'Title': 'Final Straw', 'URL': '../lyrics/rem/finalstraw.html'},
#  {'Title': 'I Wanted To Be Wrong',
#   'URL': '../lyrics/rem/iwantedtobewrong.html'},
#  {'Title': 'Wanderlust', 'URL': '../lyrics/rem/wanderlust.html'},
#  {'Title': 'The Boy In The Well', 'URL': '../lyrics/rem/theboyinthewell.html'},
#  {'Title': 'Aftermath', 'URL': '../lyrics/rem/aftermath.html'},
#  {'Title': 'High Speed Train', 'URL': '../lyrics/rem/highspeedtrain.html'},
#  {'Title': 'The Worst Joke Ever',
#   'URL': '../lyrics/rem/theworstjokeever.html'},
#  {'Title': 'The Ascent Of Man', 'URL': '../lyrics/rem/theascentofman.html'},
#  {'Title': 'Around The Sun', 'URL': '../lyrics/rem/aroundthesun.html'},
#  {'Title': 'Living Well Is The Best Revenge',
#   'URL': '../lyrics/rem/livingwellisthebestrevenge.html'},
#  {'Title': 'Man-Sized Wreath', 'URL': '../lyrics/rem/mansizedwreath.html'},
#  {'Title': 'Supernatural Superserious',
#   'URL': '../lyrics/rem/supernaturalsuperserious.html'},
#  {'Title': 'Hollow Man', 'URL': '../lyrics/rem/hollowman.html'},
#  {'Title': 'Houston', 'URL': '../lyrics/rem/houston.html'},
#  {'Title': 'Accelerate', 'URL': '../lyrics/rem/accelerate.html'},
#  {'Title': 'Until The Day Is Done',
#   'URL': '../lyrics/rem/untilthedayisdone.html'},
#  {'Title': 'Mr. Richards', 'URL': '../lyrics/rem/mrrichards.html'},
#  {'Title': 'Sing For The Submarine',
#   'URL': '../lyrics/rem/singforthesubmarine.html'},
#  {'Title': 'Horse To Water', 'URL': '../lyrics/rem/horsetowater.html'},
#  {'Title': "I'm Gonna DJ", 'URL': '../lyrics/rem/imgonnadj.html'},
#  {'Title': 'Discoverer', 'URL': '../lyrics/rem/discoverer.html'},
#  {'Title': 'All The Best', 'URL': '../lyrics/rem/allthebest.html'},
#  {'Title': 'Ã\x9cberlin', 'URL': '../lyrics/rem/berlin.html'},
#  {'Title': 'Oh My Heart', 'URL': '../lyrics/rem/ohmyheart.html'},
#  {'Title': 'It Happened Today', 'URL': '../lyrics/rem/ithappenedtoday.html'},
#  {'Title': 'Every Day Is Yours To Win',
#   'URL': '../lyrics/rem/everydayisyourstowin.html'},
#  {'Title': 'Mine Smell Like Honey',
#   'URL': '../lyrics/rem/minesmelllikehoney.html'},
#  {'Title': 'Walk It Back', 'URL': '../lyrics/rem/walkitback.html'},
#  {'Title': 'Alligator Aviator Autopilot Antimatter',
#   'URL': '../lyrics/rem/alligatoraviatorautopilotantimatter.html'},
#  {'Title': 'That Someone Is You',
#   'URL': '../lyrics/rem/thatsomeoneisyou.html'},
#  {'Title': 'Me, Marlon Brando, Marlon Brando And I',
#   'URL': '../lyrics/rem/memarlonbrandomarlonbrandoandi.html'},
#  {'Title': 'Blue', 'URL': '../lyrics/rem/blue.html'},
#  {'Title': 'A Month Of Saturdays',
#   'URL': '../lyrics/rem/amonthofsaturdays.html'},
#  {'Title': 'Animal', 'URL': '../lyrics/rem/animal.html'},
#  {'Title': 'Bad Day', 'URL': '../lyrics/rem/badday.html'},
#  {'Title': 'Losing My Religion 2 (Demo)',
#   'URL': '../lyrics/rem/losingmyreligion2demo.html'},
#  {'Title': "Mike's Pop Song", 'URL': '../lyrics/rem/mikespopsong.html'},
#  {'Title': 'Photograph', 'URL': '../lyrics/rem/photograph.html'},
#  {'Title': 'Romance', 'URL': '../lyrics/rem/romance.html'},
#  {'Title': 'The Great Beyond', 'URL': '../lyrics/rem/thegreatbeyond.html'},
#  {'Title': 'We All Go Back To Where We Belong',
#   'URL': '../lyrics/rem/weallgobacktowherewebelong.html'}]

# %%
df = pd.DataFrame(rows)

# %%
df['URL'] = df['URL'].astype(str)
df['URL'] = df.URL.str.extract(r"(/lyrics.*)")

# %%
df.head()
# Out:
#                     Title                                   URL
# 0       Radio Free Europe      /lyrics/rem/radiofreeeurope.html
# 1              Pilgrimage           /lyrics/rem/pilgrimage.html
# 2                Laughing             /lyrics/rem/laughing.html
# 3  Talk About The Passion  /lyrics/rem/talkaboutthepassion.html
# 4             Moral Kiosk           /lyrics/rem/moralkiosk.html

# %%
df.to_csv("AZLyrics.csv", index=False)

# %% [markdown]
# ## Part II

# %%
def scrape_page(row):
    url = f"https://www.azlyrics.com{row['URL']}"
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    
    page = {}
    verses = doc.find(class_= "col-xs-12 col-lg-8 text-center").find_all('div')[-1].find_all('br')
    page['verse'] = "\n".join([verse.text for verse in verses])
    
    return pd.Series(page)

# %%
scrape_page(df.loc[3])
# Out:
# verse
# dtype: object
